# %%
from query import query
import pandas as pd
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
query(position="6115", chrom="17")
# Out:
#     SELECT * FROM parquet.`/data-raw-dev/pspark/family01` AS A
#     INNER JOIN parquet.`/data-raw-dev/pspark/summary01` AS B
#     ON
#     A.chrom = B.chrom AND
#     A.position = B.position AND
#     A.alternative = B.alternative
#     WHERE
# A.position = '6115' AND
# A.chrom = '17'
# LIMIT 1000
#     chrom  position reference alternative  var_index  allele_index split_from_multi_allelic  family_id           genotype  inheritance                                 variant_in_members    variant_in_roles variant_in_sexes chrom  position reference alternative  var_index  allele_index split_from_multi_allelic effect_type effect_gene.genes effect_gene.types effect_details.transcript_ids effect_details.details  af_parents_called_count  af_parents_called_percent  af_alternative_allele_count  af_alternative_allele_freq  af_reference_allele_count  af_reference_allele_freq
# ...

# %%
query(position="<10000", chrom="17")
# Out:
#     SELECT * FROM parquet.`/data-raw-dev/pspark/family01` AS A
#     INNER JOIN parquet.`/data-raw-dev/pspark/summary01` AS B
#     ON
#     A.chrom = B.chrom AND
#     A.position = B.position AND
#     A.alternative = B.alternative
#     WHERE
# A.position < 10000 AND
# A.chrom = '17'
# LIMIT 1000
#     chrom  position reference alternative  var_index  allele_index split_from_multi_allelic  family_id           genotype  inheritance                                 variant_in_members    variant_in_roles variant_in_sexes chrom  position reference alternative  var_index  allele_index split_from_multi_allelic effect_type effect_gene.genes effect_gene.types effect_details.transcript_ids effect_details.details  af_parents_called_count  af_parents_called_percent  af_alternative_allele_count  af_alternative_allele_freq  af_reference_allele_count  af_reference_allele_freq
# ...

# %%
query(genes='CHD8', effect_type="intron or missense",
      family_id="SF0018789", role="mom", sex='F', inheritance="mendelian")
# Out:
#     SELECT * FROM parquet.`/data-raw-dev/pspark/family01` AS A
#     INNER JOIN parquet.`/data-raw-dev/pspark/summary01` AS B
#     ON
#     A.chrom = B.chrom AND
#     A.position = B.position AND
#     A.alternative = B.alternative
#     WHERE
# inheritance = 2 AND
# array_contains(`effect_gene.genes`, 'CHD8') AND
# array_contains(variant_in_sexes, 2) AND
# family_id = 'SF0018789' AND
# array_contains(variant_in_roles, 16) AND
# (array_contains(`effect_gene.types`, 'intron') OR array_contains(`effect_gene.types`, 'missense'))
# LIMIT 1000
# ...

# %%
query(genes='CHD8', role="mom and not dad", inheritance="mendelian")
# Out:
#     SELECT * FROM parquet.`/data-raw-dev/pspark/family01` AS A
#     INNER JOIN parquet.`/data-raw-dev/pspark/summary01` AS B
#     ON
#     A.chrom = B.chrom AND
#     A.position = B.position AND
#     A.alternative = B.alternative
#     WHERE
# array_contains(`effect_gene.genes`, 'CHD8') AND
# (array_contains(variant_in_roles, 16) AND NOT array_contains(variant_in_roles, 32)) AND
# inheritance = 2
# LIMIT 1000
# ...

# %%
query(genes='CHD8', personId="SP0018789")
# Out:
#     SELECT * FROM parquet.`/data-raw-dev/pspark/family01` AS A
#     INNER JOIN parquet.`/data-raw-dev/pspark/summary01` AS B
#     ON
#     A.chrom = B.chrom AND
#     A.position = B.position AND
#     A.alternative = B.alternative
#     WHERE
# array_contains(variant_in_members, 'SP0018789') AND
# array_contains(`effect_gene.genes`, 'CHD8')
# LIMIT 1000
#   chrom  position reference alternative  var_index  allele_index split_from_multi_allelic  family_id       genotype  inheritance                     variant_in_members variant_in_roles variant_in_sexes chrom  position reference alternative  var_index  allele_index split_from_multi_allelic effect_type effect_gene.genes effect_gene.types     effect_details.transcript_ids     effect_details.details  af_parents_called_count  af_parents_called_percent  af_alternative_allele_count  af_alternative_allele_freq  af_reference_allele_count  af_reference_allele_freq
# ...

# %%
query(genes='CHD8', role="eq(mom)")
# Out:
#     SELECT * FROM parquet.`/data-raw-dev/pspark/family01` AS A
#     INNER JOIN parquet.`/data-raw-dev/pspark/summary01` AS B
#     ON
#     A.chrom = B.chrom AND
#     A.position = B.position AND
#     A.alternative = B.alternative
#     WHERE
# array_contains(`effect_gene.genes`, 'CHD8') AND
# concat_ws('|',variant_in_roles) = concat_ws('|', array(16))
# LIMIT 1000
#     chrom  position          reference    alternative  var_index  allele_index split_from_multi_allelic  family_id           genotype  inheritance variant_in_members variant_in_roles variant_in_sexes chrom  position          reference    alternative  var_index  allele_index split_from_multi_allelic effect_type effect_gene.genes      effect_gene.types     effect_details.transcript_ids                         effect_details.details  af_parents_called_count  af_parents_called_percent  af_alternative_allele_count  af_alternative_allele_freq  af_reference_allele_count  af_reference_allele_freq
# ...

# %%
query(genes='CHD8', af_reference_allele_freq="<10")
# Out:
#     SELECT * FROM parquet.`/data-raw-dev/pspark/family01` AS A
#     INNER JOIN parquet.`/data-raw-dev/pspark/summary01` AS B
#     ON
#     A.chrom = B.chrom AND
#     A.position = B.position AND
#     A.alternative = B.alternative
#     WHERE
# af_reference_allele_freq < 10 AND
# array_contains(`effect_gene.genes`, 'CHD8')
# LIMIT 1000
